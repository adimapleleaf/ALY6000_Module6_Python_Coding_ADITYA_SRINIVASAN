# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from IPython.display import Image
from IPython.core.display import HTML

# %%
df = pd.read_csv("df_new.csv")

# %%
# Check for duplicate data

dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

df[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Year, Rating, IMDb, Rotten.Tomatoes, Genre, Netflix, Amazon.Prime.Video, IMDbbins, Rotten.Tomatoesbins, New_IMDb, Combined_Average_Rating, CARbins, Year_Range]
# Index: []

# %%
df.head()
# Out:
#    Unnamed: 0                  Title  Year Rating  IMDb  Rotten.Tomatoes  \
# 0           1  Terminator: Dark Fate  2019    18+   6.2               81
# 1           2             Gemini Man  2019    13+   5.7               74
# 2           3      Rambo: Last Blood  2019    18+   6.1               72
# 3           4            The Courier  2019    18+   4.9               50
# 4           5                  Crawl  2019    18+   6.1               79
#
#                 Genre  Netflix  Amazon.Prime.Video IMDbbins  \
# 0  Action & Adventure        0                   1     Good
# 1  Action & Adventure        0                   1     Good
# 2  Action & Adventure        0                   1     Good
# 3  Action & Adventure        0                   1   Normal
# 4  Action & Adventure        0                   1     Good
#
#   Rotten.Tomatoesbins  New_IMDb  Combined_Average_Rating      CARbins  \
# 0           Excellent        62                     71.5  (66.9,73.6]
# 1                Good        57                     65.5  (60.2,66.9]
# 2                Good        61                     66.5  (60.2,66.9]
# 3              Normal        49                     49.5  (46.8,53.5]
# 4           Excellent        61                     70.0  (66.9,73.6]
#
#   Year_Range
# 0  2000:2020
# 1  2000:2020
# 2  2000:2020
# 3  2000:2020
# 4  2000:2020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               800 non-null    int64
#  1   Title                    800 non-null    object
#  2   Year                     800 non-null    int64
#  3   Rating                   800 non-null    object
#  4   IMDb                     800 non-null    float64
#  5   Rotten.Tomatoes          800 non-null    int64
#  6   Genre                    800 non-null    object
#  7   Netflix                  800 non-null    int64
#  8   Amazon.Prime.Video       800 non-null    int64
#  9   IMDbbins                 800 non-null    object
#  10  Rotten.Tomatoesbins      800 non-null    object
#  11  New_IMDb                 800 non-null    int64
#  12  Combined_Average_Rating  800 non-null    float64
#  13  CARbins                  800 non-null    object
#  14  Year_Range               800 non-null    object
# dtypes: float64(2), int64(6), object(7)
# memory usage: 93.9+ KB

# %%
df.Genre.unique()
# Out:
# array(['Action & Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
#        'Documentary', 'Drama', 'Family', 'Fantasy', 'Horror', 'Mystery',
#        'Romance', 'Thriller'], dtype=object)

# %%
#Yearly data on movies/shows from Amazon Prime Video and Netflix
plt.figure(figsize=(10,8))
fig = sns.distplot(df['Year'],color = 'limegreen')
fig.set_xlabel("Year",size=12)
fig.set_ylabel("Count of Movies or Shows",size=12)
plt.title('Distribution of Movies or TV shows in each Year',size = 15)
plt.show()
# Out:
# C:\Users\91903\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Distribution of Movies or TV shows as per IMDb Rating
plt.figure(figsize=(10,8))
fig = sns.distplot(df['IMDb'],color = '#9400d3')
fig.set_xlabel("IMDb",size=12)
fig.set_ylabel("Frequency of Movies or Shows",size=12)
plt.title('Distribution of Movies or TV shows as per IMDb Rating',size = 15)
plt.show()
# Out:
# C:\Users\91903\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Distribution of Movies or TV shows as per Rotten.Tomatoes Rating
plt.figure(figsize=(10,8))
fig = sns.distplot(df['Rotten.Tomatoes'],color = '#ff9966')
fig.set_xlabel("Rotten.Tomatoes",size=12)
fig.set_ylabel("Frequency of Movies or Shows",size=12)
plt.title('Distribution of Movies or TV shows as per Rotten.Tomatoes Rating',size = 15)
plt.show()
# Out:
# C:\Users\91903\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Distribution of Movies or TV shows as per Combined_Average_Rating
plt.figure(figsize=(10,8))
fig = sns.distplot(df['Combined_Average_Rating'],color = '#c7c96c')
fig.set_xlabel("Combined_Average_Rating",size=12)
fig.set_ylabel("Frequency of Movies or Shows",size=12)
plt.title('Distribution of Movies or TV shows as per Combined_Average_Rating',size = 15)
plt.show()
# Out:
# C:\Users\91903\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### WordCloud

# %%
from wordcloud import WordCloud

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.Title))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('Title.png')
plt.show()

# %% [markdown]
# #### Correlation Heatmap

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='Blues')
plt.show()
